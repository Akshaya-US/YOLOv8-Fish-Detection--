# %%
# !pip install ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 626.9/626.9 kB 23.1 MB/s eta 0:00:00
# ...

# %%
# !yolo task=detect mode=predict model=yolov8n.pt conf=0.25 source=/content/face6.jpg
# Out:
# ...
# 100% 6.23M/6.23M [00:00<00:00, 146MB/s]
# Ultralytics YOLOv8.0.131 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv8n summary (fused): 168 layers, 3151904 parameters, 0 gradients
#
# image 1/1 /content/face6.jpg: 640x640 1 person, 7.9ms
# Speed: 13.7ms preprocess, 7.9ms inference, 37.1ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict

# %%
from IPython.display import Image
Image("/content/runs/detect/predict/face6.jpg", width=100, height=100)

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="Xnn8kFPRUQKY5idZY7xm")
project = rf.workspace("brad-dwyer").project("aquarium-combined")
dataset = project.version(6).download("yolov8")
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 7.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 16.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.8/67.8 kB 8.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.6/55.6 kB 6.9 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 7.6 MB/s eta 0:00:00
# ...
#   Created wheel for wget: filename=wget-3.2-py3-none-any.whl size=9657 sha256=d41c5ebb1e1e9f09aa70bb01aaa5ce3714dcca6d7e107767abb2f96c2c10cc3e
#   Stored in directory: /root/.cache/pip/wheels/8b/f1/7f/5c94f0a7a505ca1c81cd1d9208ae2064675d97582078e6c769
# Successfully built wget
# ...
#   Attempting uninstall: pyparsing
#     Found existing installation: pyparsing 3.1.0
#     Uninstalling pyparsing-3.1.0:
#       Successfully uninstalled pyparsing-3.1.0
# ...

# %%
# !yolo task=detect mode=train model=yolov8s.pt data={dataset.location}/data.yaml epochs=50 imgsz=640
# Out:
# ...
# 100% 21.5M/21.5M [00:00<00:00, 27.5MB/s]
# Ultralytics YOLOv8.0.131 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt conf=0.25 source=/content/IMG_2395_jpeg_jpg.rf.f6a24153e48f7933af35ba0121ac246e.jpg
# Out:
# Ultralytics YOLOv8.0.131 🚀 Python-3.10.12 torch-2.0.1+cu118 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 168 layers, 11128293 parameters, 0 gradients
#
# image 1/1 /content/IMG_2395_jpeg_jpg.rf.f6a24153e48f7933af35ba0121ac246e.jpg: 640x480 6 fishs, 111.1ms
# Speed: 4.3ms preprocess, 111.1ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to runs/detect/predict2

# %%
Image("/content/runs/detect/predict2/IMG_2395_jpeg_jpg.rf.f6a24153e48f7933af35ba0121ac246e.jpg", width=500, height=500)
